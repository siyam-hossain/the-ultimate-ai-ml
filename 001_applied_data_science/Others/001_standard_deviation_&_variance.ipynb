# %%
import pandas as pd

# %%
data = {
    'Scores':[88,92,100,83,97,75]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Scores
# 0      88
# 1      92
# 2     100
# 3      83
# 4      97
# 5      75

# %%
std = df['Scores'].std()

print("STD: ",std)
# Out:
# STD:  9.239408350466315

# %%
var = df['Scores'].var()

print("VAR: ",var)
# Out:
# VAR:  85.36666666666666
