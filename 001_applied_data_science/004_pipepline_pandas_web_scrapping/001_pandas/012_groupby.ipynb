# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jeannicolasduval/2024-fortune-1000-companies")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 301k/301k [00:00<00:00, 686kB/s]
# Extracting files...
# Path to dataset files: C:\Users\siyam\.cache\kagglehub\datasets\jeannicolasduval\2024-fortune-1000-companies\versions\1

# %%
import os

print(os.listdir(path))
# Out:
# ['fortune1000_2024.csv', 'fortune1000_2024.parquet', 'fortune1000_companies.parquet', 'fortune1000_companyinfo.parquet']

# %%
csv_path = os.path.join(path, 'fortune1000_2024.csv')
csv_path
# Out:
# 'C:\\Users\\siyam\\.cache\\kagglehub\\datasets\\jeannicolasduval\\2024-fortune-1000-companies\\versions\\1\\fortune1000_2024.csv'

# %%
import pandas as pd

# %%
data = pd.read_csv(csv_path)

# %%
# data = pd.read_csv(
#     csv_path,
#     encoding="utf-8",
#     encoding_errors="replace"
# )

data.head()
# Out:
#    Rank             Company Ticker       Sector  \
# 0     1             Walmart    WMT    Retailing
# 1     2              Amazon   AMZN    Retailing
# 2     3               Apple   AAPL   Technology
# 3     4  UnitedHealth Group    UNH  Health Care
# 4     5  Berkshire Hathaway   BRKA   Financials
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# 3   Health Care: Insurance and Managed Care        yes             no
# 4  Insurance: Property and Casualty (Stock)        yes             no
#
#   FemaleCEO Growth_in_Jobs  Change_in_Rank  ...   Assets_M  \
# 0        no             no             0.0  ...   252399.0
# 1        no             no             0.0  ...   527854.0
# 2        no             no             1.0  ...   352583.0
# ...

# %%
company = pd.read_csv(csv_path)
company.head(2)
# Out:
#    Rank  Company Ticker     Sector                         Industry  \
# 0     1  Walmart    WMT  Retailing            General Merchandisers
# 1     2   Amazon   AMZN  Retailing  Internet Services and Retailing
#
#   Profitable Founder_is_CEO FemaleCEO Growth_in_Jobs  Change_in_Rank  ...  \
# 0        yes             no        no             no             0.0  ...
# 1        yes             no        no             no             0.0  ...
#
#    Assets_M                  CEO Country HeadquartersCity HeadquartersState  \
# 0  252399.0  C. Douglas McMillon    U.S.      Bentonville          Arkansas
# 1  527854.0      Andrew R. Jassy    U.S.          Seattle        Washington
#
#                          Website  CompanyType  \
# 0  https://www.stock.walmart.com       Public
# 1         https://www.amazon.com       Public
#
#                                             Footnote  MarketCap_Updated_M  \
# 0  Figures are for fiscal year ended Jan. 31, 202...             559911.0
# ...

# %%
sectors = company.groupby('Sector')

# %%
sectors

# %%
len(company)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense               19
# Apparel                           15
# Business Services                 59
# Chemicals                         26
# Energy                           107
# Engineering & Construction        31
# Financials                       163
# Food & Drug Stores                 9
# Food, Beverages & Tobacco         35
# Health Care                       80
# Hotels, Restaurants & Leisure     29
# Household Products                20
# Industrials                       48
# Materials                         47
# Media                             26
# Motor Vehicles & Parts            21
# Retailing                         72
# Technology                       115
# Telecommunications                 9
# Transportation                    39
# Wholesalers                       30
# dtype: int64

# %%
sectors.size().sort_values(ascending=False)
# Out:
# Sector
# Financials                       163
# Technology                       115
# Energy                           107
# Health Care                       80
# Retailing                         72
# Business Services                 59
# Industrials                       48
# Materials                         47
# Transportation                    39
# Food, Beverages & Tobacco         35
# Engineering & Construction        31
# Wholesalers                       30
# Hotels, Restaurants & Leisure     29
# Chemicals                         26
# Media                             26
# Motor Vehicles & Parts            21
# Household Products                20
# Aerospace & Defense               19
# Apparel                           15
# Food & Drug Stores                 9
# Telecommunications                 9
# dtype: int64

# %%
sectors.first()
# Out:
#                                Rank                 Company Ticker  \
# Sector
# Aerospace & Defense              52                  Boeing     BA
# Apparel                          88                    Nike    NKE
# Business Services               135                    Visa      V
# Chemicals                        99                     Dow    DOW
# Energy                            7             Exxon Mobil    XOM
# Engineering & Construction      120             D.R. Horton    DHI
# Financials                        5      Berkshire Hathaway   BRKA
# Food & Drug Stores               25                  Kroger     KR
# Food, Beverages & Tobacco        43  Archer Daniels Midland    ADM
# Health Care                       4      UnitedHealth Group    UNH
# Hotels, Restaurants & Leisure   116               Starbucks   SBUX
# Household Products               50        Procter & Gamble     PG
# Industrials                      56        General Electric     GE
# ...

# %%
sectors.last()
# Out:
#                                Rank                       Company Ticker  \
# Sector
# Aerospace & Defense             999              BWX Technologies   BWXT
# Apparel                         975                Kontoor Brands    KTB
# Business Services              1000  Clear Channel Outdoor Hldgs.    CCO
# Chemicals                       994                Mativ Holdings   MATV
# Energy                          986                  Talen Energy   TLNE
# Engineering & Construction      976              Skyline Champion    SKY
# Financials                      990               AGNC Investment   AGNC
# Food & Drug Stores              750        Grocery Outlet Holding     GO
# Food, Beverages & Tobacco       979                     Universal    UVV
# Health Care                     998                Exact Sciences   EXAS
# Hotels, Restaurants & Leisure   934           Peloton Interactive   PTON
# Household Products              896            Energizer Holdings    ENR
# ...

# %% [markdown]
# ### **Groups**
#
# + returning a dictionary of key
# + here every key represents one group
# + key return the all members of that perticular group

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': [51, 54, 56, 103, 108, 208, 307, 356, 532, 536, 564, 591, 607, 751, 841, 892, 906, 918, 998], 'Apparel': [87, 354, 424, 464, 530, 543, 556, 576, 589, 752, 800, 818, 872, 900, 974], 'Business Services': [134, 144, 163, 185, 198, 214, 218, 219, 227, 248, 275, 286, 287, 297, 328, 371, 409, 436, 460, 540, 546, 563, 567, 573, 603, 611, 624, 630, 640, 650, 654, 655, 690, 693, 701, 716, 722, 734, 765, 768, 780, 788, 795, 816, 834, 848, 877, 879, 916, 925, 949, 959, 960, 966, 984, 987, 991, 992, 999], 'Chemicals': [98, 133, 175, 225, 268, 306, 321, 325, 326, 355, 368, 411, 425, 491, 521, 534, 554, 566, 687, 758, 809, 813, 862, 955, 973, 993], 'Energy': [6, 14, 23, 25, 28, 50, 67, 89, 91, 92, 111, 136, 147, 148, 149, 151, 160, 162, 164, 166, 168, 176, 177, 186, 199, 211, 216, 229, 231, 243, 245, 249, 255, 267, 270, 282, 288, 301, 317, 318, 330, 338, 347, 348, 358, 370, 372, 377, 433, 434, 438, 439, 440, 441, 443, 448, 450, 453, 454, 477, 493, 509, 510, 526, 538, 574, 5
# ...

# %%
type(sectors.groups)
# Out:
# pandas.io.formats.printing.PrettyDict

# %%
company.iloc[
    51,
    :
]
# Out:
# Rank                                                            52
# Company                                                     Boeing
# Ticker                                                          BA
# Sector                                         Aerospace & Defense
# Industry                                       Aerospace & Defense
# Profitable                                                      no
# Founder_is_CEO                                                  no
# FemaleCEO                                                       no
# Growth_in_Jobs                                                 yes
# Change_in_Rank                                                 6.0
# Gained_in_Rank                                                 yes
# Dropped_in_Rank                                                 no
# Newcomer_to_the_Fortune500                                      no
# Global500                                                      yes
# ...

# %%
company.iloc[
    103,
    :
]
# Out:
# Rank                                                           104
# Company                                           General Dynamics
# Ticker                                                          GD
# Sector                                         Aerospace & Defense
# Industry                                       Aerospace & Defense
# Profitable                                                     yes
# Founder_is_CEO                                                  no
# FemaleCEO                                                      yes
# Growth_in_Jobs                                                 yes
# Change_in_Rank                                                 1.0
# Gained_in_Rank                                                 yes
# Dropped_in_Rank                                                 no
# Newcomer_to_the_Fortune500                                      no
# Global500                                                      yes
# ...

# %% [markdown]
# ### **get group**

# %%
sectors.get_group('Energy').head()
# Out:
#     Rank             Company Ticker  Sector            Industry Profitable  \
# 6      7         Exxon Mobil    XOM  Energy  Petroleum Refining        yes
# 14    15             Chevron    CVX  Energy  Petroleum Refining        yes
# 23    24  Marathon Petroleum    MPC  Energy  Petroleum Refining        yes
# 25    26         Phillips 66    PSX  Energy  Petroleum Refining        yes
# 28    29       Valero Energy    VLO  Energy  Petroleum Refining        yes
#
#    Founder_is_CEO FemaleCEO Growth_in_Jobs  Change_in_Rank  ...  Assets_M  \
# 6              no        no             no            -4.0  ...  376317.0
# 14             no        no            yes            -5.0  ...  261632.0
# 23             no        no            yes            -8.0  ...   85987.0
# 25             no        no            yes            -9.0  ...   75501.0
# 28             no        no            yes           -11.0  ...   63056.0
#
#                   CEO Country HeadquartersCity HeadquartersState  \
# ...

# %%
sectors.get_group('Apparel').head()
# Out:
#      Rank          Company Ticker   Sector Industry Profitable Founder_is_CEO  \
# 87     88             Nike    NKE  Apparel  Apparel        yes             no
# 354   355               VF    VFC  Apparel  Apparel        yes             no
# 424   425              PVH    PVH  Apparel  Apparel        yes             no
# 464   465  Skechers U.S.A.    SKX  Apparel  Apparel        yes            yes
# 530   531         Tapestry    TPR  Apparel  Apparel        yes             no
#
#     FemaleCEO Growth_in_Jobs  Change_in_Rank  ... Assets_M  \
# 87         no            yes             5.0  ...  37531.0
# 354        no             no            -6.0  ...  13990.5
# 424        no             no            -3.0  ...  11172.9
# 464        no            yes            23.0  ...   7547.4
# 530       yes            yes            -4.0  ...   7116.8
#
#                        CEO Country HeadquartersCity HeadquartersState  \
# ...

# %%
sectors.get_group('Apparel').size
# Out:
# 480

# %% [markdown]
# **Sum**

# %%
sectors['Revenues_M'].sum()
# Out:
# Sector
# Aerospace & Defense               389260.7
# Apparel                           130599.2
# Business Services                 491570.8
# Chemicals                         285942.3
# Energy                           2289632.9
# Engineering & Construction        288798.4
# Financials                       3735496.8
# Food & Drug Stores                469792.3
# Food, Beverages & Tobacco         697337.6
# Health Care                      3104833.3
# Hotels, Restaurants & Leisure     249135.1
# Household Products                237277.2
# Industrials                       574132.1
# Materials                         402390.6
# Media                             327392.8
# Motor Vehicles & Parts            611661.3
# Retailing                        2650287.8
# Technology                       2420894.6
# Telecommunications                484301.7
# Transportation                    611703.5
# Wholesalers                       512623.2
# Name: Revenues_M, dtype: float64

# %%
sectors['Revenues_M'].mean()
# Out:
# Sector
# Aerospace & Defense              20487.405263
# Apparel                           8706.613333
# Business Services                 8331.708475
# Chemicals                        10997.780769
# Energy                           21398.438318
# Engineering & Construction        9316.077419
# Financials                       22917.158282
# Food & Drug Stores               52199.144444
# Food, Beverages & Tobacco        19923.931429
# Health Care                      38810.416250
# Hotels, Restaurants & Leisure     8590.865517
# Household Products               11863.860000
# Industrials                      11961.085417
# Materials                         8561.502128
# Media                            12592.030769
# Motor Vehicles & Parts           29126.728571
# Retailing                        36809.552778
# Technology                       21051.257391
# Telecommunications               53811.300000
# Transportation                   15684.705128
# ...

# %%
sectors[
    ['Revenues_M','Profits_M']
].mean().sort_values(
    
    by=['Revenues_M','Profits_M'],
    ascending=[False, False]
)
# Out:
#                                  Revenues_M    Profits_M
# Sector
# Telecommunications             53811.300000  3726.788889
# Food & Drug Stores             52199.144444   538.833333
# Health Care                    38810.416250  2084.101250
# Retailing                      36809.552778  1566.693056
# Motor Vehicles & Parts         29126.728571  1520.600000
# Financials                     22917.158282  2568.457669
# Energy                         21398.438318  2265.521698
# Technology                     21051.257391  3976.306140
# Aerospace & Defense            20487.405263  1051.121053
# Food, Beverages & Tobacco      19923.931429  1927.680000
# Wholesalers                    17087.440000   524.690000
# Transportation                 15684.705128  1003.543590
# Media                          12592.030769   153.111538
# Industrials                    11961.085417  1607.697917
# Household Products             11863.860000  1100.360000
# ...
