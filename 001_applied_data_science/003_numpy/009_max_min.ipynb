# %%
import numpy as np
from numpy import random

# %%
m = random.rand(3,3)
m
# Out:
# array([[0.48112347, 0.62804586, 0.86018723],
#        [0.20254751, 0.44068326, 0.63986151],
#        [0.98118322, 0.31530581, 0.91046603]])

# %%
m.max()
# Out:
# np.float64(0.9811832230403804)

# %% [markdown]
# help to calculate column wise max

# %%
m.max(axis=0)
# Out:
# array([0.98118322, 0.62804586, 0.91046603])

# %% [markdown]
# help to calculate row wise max

# %%
m.max(axis=1)
# Out:
# array([0.86018723, 0.63986151, 0.98118322])

# %%
m.min(axis=0)
# Out:
# array([0.20254751, 0.31530581, 0.63986151])

# %%
m.min(axis=1)
# Out:
# array([0.48112347, 0.20254751, 0.31530581])
