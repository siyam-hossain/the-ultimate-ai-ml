# %%
import numpy as np

# %%
d = np.array([1,2,3,4])
d
# Out:
# array([1, 2, 3, 4])

# %%
for item in d:
    print(item, end = " ")
# Out:
# 1 2 3 4

# %%
m = np.arange(0,4).reshape(2,2)
m
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
for row in m:
    print("row:" )
    for col in row:
        print(col, end = " ")
    print()
# Out:
# row:
# 0 1
# row:
# 2 3
