# %%
import numpy as np

# %%
mylist = [1,2,3,4,5]
mylist[1:4]
# Out:
# [2, 3, 4]

# %%
mylist[3:5]
# Out:
# [4, 5]

# %%
x = np.array(
    [1,2,3,4,5]
)
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
x[1:4]
# Out:
# array([2, 3, 4])

# %%
x[3:5]
# Out:
# array([4, 5])

# %%
x[::]
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# x[ start : end : step ]

# %%
x[::2]
# Out:
# array([1, 3, 5])
