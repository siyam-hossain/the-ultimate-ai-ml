# %% [markdown]
# + python -m venv env
# + source env/Scripts/activate (windows)
# + source env/bin/activate (linux/mac)
#
# + install necessary package
# + select python kernel to env

# %%
import sys
sys.executable
# Out:
# 'd:\\Rat_Race\\the-ultimate-ai-ml\\001_applied_data_science\\003_numpy\\env\\Scripts\\python.exe'

# %%
import numpy as np

# %%
v = np.array([1,2,3,4])
v
# Out:
# array([1, 2, 3, 4])

# %%
m = np.array(
    [
        [1,2,3,4,5,6],
        [2,4,5,6,7,8]
    ]
)
m
# Out:
# array([[1, 2, 3, 4, 5, 6],
#        [2, 4, 5, 6, 7, 8]])

# %%
type(v)
# Out:
# numpy.ndarray

# %%
type(m)
# Out:
# numpy.ndarray
