# %%
import numpy as np

# %%
name = 'siyam hossain'

# %%
name[-1]
# Out:
# 'n'

# %%
name[0]
# Out:
# 's'

# %%
m = np.array(
    [
        [1,2,3],
        [4,5,6]
    ]
)
m
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
m[0]
# Out:
# array([1, 2, 3])

# %%
m[0,1]
# Out:
# np.int64(2)

# %%
m[0,0]
# Out:
# np.int64(1)

# %%
m[1,2]
# Out:
# np.int64(6)

# %%
m
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
m[ : , 1]
# Out:
# array([2, 5])

# %%
m[1,2] = 65
m
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5, 65]])
